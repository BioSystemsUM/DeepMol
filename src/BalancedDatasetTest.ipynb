# %%
from Dataset.Dataset import CSVLoader, NumpyDataset

import numpy as np
import random

# %%
#Load Dataset
dataset = CSVLoader('preprocessed_dataset_wfoodb.csv', 'Smiles', ['Class'], 'ID')#, chunk_size=2000)
print(dataset.get_shape())
# Out:
# (23290,) (23290,) (0,) (23290,)
# ((23290,), (23290,), (0,), (23290,))

# %%
#Separate sweeteners from non sweeteners
sweets_indexes = np.where(dataset.y == 1)
sweets = dataset.select(sweets_indexes)

non_sweets_indexes = np.where(dataset.y == 0)
non_sweets = dataset.select(non_sweets_indexes)

# %%
#Ratio between sweeteners and non sweeteners
n_balanced_datasets = int(np.floor(len(non_sweets.y)/len(sweets.y)))
n_balanced_datasets
# Out:
# 16

# %%
indexes = list(range(0, len(non_sweets.y)))

def partition (list_in, n):
    random.shuffle(list_in)
    return [list_in[i::n] for i in range(n)]

dataset_indexes = partition(indexes, n_balanced_datasets)


# TODO: Check merge method
balanced_datasets = []
for i, di in enumerate(dataset_indexes):
    ds = non_sweets.select(di)
    print(ds.get_shape())
    print(type(ds))
    ds = ds.merge([ds, sweets])
    print(ds.get_shape())
    balanced_datasets.append(ds)
# Out:
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
# ((1373,), (1373,), (0,), (1373,))
# <class 'Dataset.Dataset.NumpyDataset'>
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# Features are not the same length/type...
# Recalculate features for all inputs!
# Appending empty array in dataset features!
# ((4068,), (4068,), (0,), (4068,))
