# %%
from Dataset.Dataset import CSVLoader, NumpyDataset
from compoundFeaturization.rdkitFingerprints import MorganFingerprint
from featureSelection.baseFeatureSelector import LowVarianceFS
from splitters.splitters import SingletaskStratifiedSplitter
from models.sklearnModels import SklearnModel
from metrics.Metrics import Metric
from metrics.metricsFunctions import roc_auc_score, precision_score, accuracy_score, confusion_matrix, classification_report
from parameterOptimization.HyperparameterOpt import GridHyperparamOpt

from sklearn.ensemble import RandomForestClassifier

import numpy as np
import random

# %%
#Load Dataset
dataset = CSVLoader('preprocessed_dataset_wfoodb.csv', 'Smiles', ['Class'], 'ID')#, chunk_size=2000)
print(dataset.get_shape())
# Out:
# (23290,) (23290,) (0,) (23290,)
# ((23290,), (23290,), (0,), (23290,))

# %%
#Separate sweeteners from non sweeteners
sweets_indexes = np.where(dataset.y == 1)
sweets = dataset.select(sweets_indexes)

non_sweets_indexes = np.where(dataset.y == 0)
non_sweets = dataset.select(non_sweets_indexes)

# %%
#Ratio between sweeteners and non sweeteners
n_balanced_datasets = int(np.floor(len(non_sweets.y)/len(sweets.y)))
n_balanced_datasets
# Out:
# 16

# %%
indexes = list(range(0, len(non_sweets.y)))

def partition (list_in, n):
    random.shuffle(list_in)
    return [list_in[i::n] for i in range(n)]

dataset_indexes = partition(indexes, n_balanced_datasets)


# TODO: Check merge method
balanced_datasets = []
for i, di in enumerate(dataset_indexes):
    ds = non_sweets.select(di)
    ds = ds.merge([sweets])
    balanced_datasets.append(ds)

# %%
for dataset in balanced_datasets:
    #Featurization
    #dataset = balanced_datasets[0]
    dataset = MorganFingerprint().featurize(dataset)
    dataset.get_shape()

    #Feature Selection
    dataset = LowVarianceFS(0.15).featureSelection(dataset)
    dataset.get_shape()

    #Data Split
    splitter = SingletaskStratifiedSplitter()
    train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(dataset=dataset, frac_train=0.6, 
                                                                                 frac_valid=0.2, frac_test=0.2)

    #metrics
    metrics = [Metric(roc_auc_score), Metric(precision_score), Metric(accuracy_score), Metric(confusion_matrix), 
               Metric(classification_report)]

    #Build a model function for hyperparameter optimization
    def rf_model_builder(n_estimators, max_features, class_weight, model_dir=None):
        rf_model = RandomForestClassifier(n_estimators=n_estimators, max_features=max_features, 
                                          class_weight=class_weight)
        return SklearnModel(rf_model, model_dir)

    params_dict_rf = {"n_estimators": [10, 100],
                      "max_features": ["auto", "sqrt", "log2", None],
                      "class_weight": [{0: 1., 1: 1.}, {0: 1., 1: 5}, {0: 1., 1: 10}]
                      }

    #Hyperparameter Optimization
    optimizer = GridHyperparamOpt(rf_model_builder)

    best_rf, best_hyperparams, all_results = optimizer.hyperparam_search(params_dict_rf, train_dataset, 
                                                                         valid_dataset, Metric(roc_auc_score))

    print('#################')
    print(best_hyperparams)
    print(best_rf)

    #Evaluate best model
    best_rf.evaluate(test_dataset, metrics)
# Out:
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8098237124092637
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.809824
# 	best_validation_score so far: 0.809824
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.835361216730038
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.835361
# 	best_validation_score so far: 0.835361
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8147805046664361
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.814781
# 	best_validation_score so far: 0.835361
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8074248185274802
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.807425
# 	best_validation_score so far: 0.835361
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.820649844452126
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.820650
# 	best_validation_score so far: 0.835361
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8124645696508814
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.812465
# 	best_validation_score so far: 0.835361
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8069270653301072
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.806927
# 	best_validation_score so far: 0.835361
# Fitting model 8/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8127134462495679
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.812713
# 	best_validation_score so far: 0.835361
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8404839267196681
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.840484
# 	best_validation_score so far: 0.840484
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8484203249222262
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.848420
# 	best_validation_score so far: 0.848420
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8316418942274455
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.831642
# 	best_validation_score so far: 0.848420
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8392464569650882
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.839246
# 	best_validation_score so far: 0.848420
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8449498790183201
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.844950
# 	best_validation_score so far: 0.848420
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8345316280677497
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.834532
# 	best_validation_score so far: 0.848420
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8256066367092983
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.825607
# 	best_validation_score so far: 0.848420
# roc_auc_score:
#  0.95499262627504
# Best hyperparameters: (100, 'auto', {0: 1.0, 1: 5})
# train_score: 0.954993
# validation_score: 0.848420
# #################
# (100, 'auto', {0: 1.0, 1: 5})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 5}),
#              model_dir='/tmp/tmp8ng4e4lq')
# roc_auc_score:
#  0.8314532183145321
# precision_score:
#  0.8056537102473498
# accuracy_score:
#  0.8308550185873605
# confusion_matrix:
#  [[219  55]
#  [ 36 228]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       274
#            1       0.81      0.86      0.83       264
#
#     accuracy                           0.83       538
#    macro avg       0.83      0.83      0.83       538
# weighted avg       0.83      0.83      0.83       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7910611821638437
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.791061
# 	best_validation_score so far: 0.791061
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7856066367092983
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.785607
# 	best_validation_score so far: 0.791061
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8089111648807467
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.808911
# 	best_validation_score so far: 0.808911
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7821361908053922
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.782136
# 	best_validation_score so far: 0.808911
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8165157276183892
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.816516
# 	best_validation_score so far: 0.816516
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8134600760456274
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.813460
# 	best_validation_score so far: 0.816516
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7873418596612513
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.787342
# 	best_validation_score so far: 0.816516
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8223021085378499
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.822302
# 	best_validation_score so far: 0.822302
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.825689595575527
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.825690
# 	best_validation_score so far: 0.825690
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8149464223988939
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.814946
# 	best_validation_score so far: 0.825690
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8293259592118908
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.829326
# 	best_validation_score so far: 0.829326
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8150293812651227
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.815029
# 	best_validation_score so far: 0.829326
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8168475630833045
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.816848
# 	best_validation_score so far: 0.829326
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8180850328378846
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.818085
# 	best_validation_score so far: 0.829326
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8033736605599722
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.803374
# 	best_validation_score so far: 0.829326
# roc_auc_score:
#  0.9642223495490735
# Best hyperparameters: (100, 'log2', {0: 1.0, 1: 1.0})
# train_score: 0.964222
# validation_score: 0.829326
# #################
# (100, 'log2', {0: 1.0, 1: 1.0})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 1.0},
#                                           max_features='log2'),
#              model_dir='/tmp/tmpvwjv6xd9')
# roc_auc_score:
#  0.7743657103352921
# precision_score:
#  0.7406143344709898
# accuracy_score:
#  0.7732342007434945
# confusion_matrix:
#  [[199  76]
#  [ 46 217]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.72      0.77       275
#            1       0.74      0.83      0.78       263
#
#     accuracy                           0.77       538
#    macro avg       0.78      0.77      0.77       538
# weighted avg       0.78      0.77      0.77       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7825533797986504
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.782553
# 	best_validation_score so far: 0.782553
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7805481801084191
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.780548
# 	best_validation_score so far: 0.782553
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7745325810377255
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.774533
# 	best_validation_score so far: 0.782553
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7911273370948114
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.791127
# 	best_validation_score so far: 0.791127
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7854021462551168
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.785402
# 	best_validation_score so far: 0.791127
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.802093705055869
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.802094
# 	best_validation_score so far: 0.802094
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7853053435114503
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.785305
# 	best_validation_score so far: 0.802094
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8185916583692886
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.818592
# 	best_validation_score so far: 0.818592
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.789412545635579
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.789413
# 	best_validation_score so far: 0.818592
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7928421285540436
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.792842
# 	best_validation_score so far: 0.818592
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8006693218276358
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.800669
# 	best_validation_score so far: 0.818592
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8166832614227237
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.816683
# 	best_validation_score so far: 0.818592
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7967557251908397
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.796756
# 	best_validation_score so far: 0.818592
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8033244827967696
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.803324
# 	best_validation_score so far: 0.818592
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7959813032415091
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.795981
# 	best_validation_score so far: 0.818592
# roc_auc_score:
#  0.9519979477505903
# Best hyperparameters: (100, 'auto', {0: 1.0, 1: 1.0})
# train_score: 0.951998
# validation_score: 0.818592
# #################
# (100, 'auto', {0: 1.0, 1: 1.0})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 1.0}),
#              model_dir='/tmp/tmp35s451id')
# roc_auc_score:
#  0.7925790754257909
# precision_score:
#  0.7638888888888888
# accuracy_score:
#  0.79182156133829
# confusion_matrix:
#  [[206  68]
#  [ 44 220]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.75      0.79       274
#            1       0.76      0.83      0.80       264
#
#     accuracy                           0.79       538
#    macro avg       0.79      0.79      0.79       538
# weighted avg       0.79      0.79      0.79       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# RDKit ERROR: [17:09:20] Explicit valence for atom # 3 B, 4, is greater than permitted
# error in smile: OB1O[B]2(O)OB(O)O[B](O)(O1)O2
# Featurizing datapoint 2000
# Elements with indexes:  [1259]  were removed due to the presence of NAs!
# The elements in question are:  ['OB1O[B]2(O)OB(O)O[B](O)(O1)O2']
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8048669201520912
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.804867
# 	best_validation_score so far: 0.804867
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7969305219495334
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.796931
# 	best_validation_score so far: 0.804867
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8063532665053579
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.806353
# 	best_validation_score so far: 0.806353
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8123055651572763
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.812306
# 	best_validation_score so far: 0.812306
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8027169028689942
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.802717
# 	best_validation_score so far: 0.812306
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7811475976494988
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.781148
# 	best_validation_score so far: 0.812306
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.793625993778085
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.793626
# 	best_validation_score so far: 0.812306
# Fitting model 8/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8008157621845836
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.800816
# 	best_validation_score so far: 0.812306
# Fitting model 9/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7972623574144487
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.797262
# 	best_validation_score so far: 0.812306
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8095748358105772
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.809575
# 	best_validation_score so far: 0.812306
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.812388524023505
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.812389
# 	best_validation_score so far: 0.812389
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8142896647079156
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.814290
# 	best_validation_score so far: 0.814290
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8142896647079156
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.814290
# 	best_validation_score so far: 0.814290
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8041202903560317
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.804120
# 	best_validation_score so far: 0.814290
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7932941583131697
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.793294
# 	best_validation_score so far: 0.814290
# roc_auc_score:
#  0.9573743496473849
# Best hyperparameters: (100, 'log2', {0: 1.0, 1: 5})
# train_score: 0.957374
# validation_score: 0.814290
# #################
# (100, 'log2', {0: 1.0, 1: 5})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 5},
#                                           max_features='log2'),
#              model_dir='/tmp/tmpo2jgvt4j')
# roc_auc_score:
#  0.8116567131165672
# precision_score:
#  0.7682119205298014
# accuracy_score:
#  0.8104089219330854
# confusion_matrix:
#  [[204  70]
#  [ 32 232]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80       274
#            1       0.77      0.88      0.82       264
#
#     accuracy                           0.81       538
#    macro avg       0.82      0.81      0.81       538
# weighted avg       0.82      0.81      0.81       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8059748949347489
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.805975
# 	best_validation_score so far: 0.805975
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7988829904888299
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.798883
# 	best_validation_score so far: 0.805975
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.794403892944039
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.794404
# 	best_validation_score so far: 0.805975
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7913763547887636
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.791376
# 	best_validation_score so far: 0.805975
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8209881663348817
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.820988
# 	best_validation_score so far: 0.820988
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7965743198407433
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.796574
# 	best_validation_score so far: 0.820988
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8079379562043796
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.807938
# 	best_validation_score so far: 0.820988
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8169929219199291
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.816993
# 	best_validation_score so far: 0.820988
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.815168104401681
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.815168
# 	best_validation_score so far: 0.820988
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8226056182260564
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.822606
# 	best_validation_score so far: 0.822606
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.813066799380668
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.813067
# 	best_validation_score so far: 0.822606
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8152372262773723
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.815237
# 	best_validation_score so far: 0.822606
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8211264100862641
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.821126
# 	best_validation_score so far: 0.822606
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8019105286441053
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.801911
# 	best_validation_score so far: 0.822606
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8110346162353461
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.811035
# 	best_validation_score so far: 0.822606
# roc_auc_score:
#  0.9593446601941747
# Best hyperparameters: (100, 'sqrt', {0: 1.0, 1: 10})
# train_score: 0.959345
# validation_score: 0.822606
# #################
# (100, 'sqrt', {0: 1.0, 1: 10})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 10},
#                                           max_features='sqrt'),
#              model_dir='/tmp/tmpwo2vh67i')
# roc_auc_score:
#  0.8244521258209472
# precision_score:
#  0.7896551724137931
# accuracy_score:
#  0.8234200743494424
# confusion_matrix:
#  [[214  61]
#  [ 34 229]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       275
#            1       0.79      0.87      0.83       263
#
#     accuracy                           0.82       538
#    macro avg       0.83      0.82      0.82       538
# weighted avg       0.83      0.82      0.82       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8153063481530635
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.815306
# 	best_validation_score so far: 0.815306
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7766395708913957
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.776640
# 	best_validation_score so far: 0.815306
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8044265649192657
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.804427
# 	best_validation_score so far: 0.815306
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7893441716434416
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.789344
# 	best_validation_score so far: 0.815306
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7927864410528644
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.792786
# 	best_validation_score so far: 0.815306
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7821140234461402
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.782114
# 	best_validation_score so far: 0.815306
# Fitting model 7/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8099010174740101
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.809901
# 	best_validation_score so far: 0.815306
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8022561380225615
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.802256
# 	best_validation_score so far: 0.815306
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7969890510948905
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.796989
# 	best_validation_score so far: 0.815306
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8005695642556956
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.800570
# 	best_validation_score so far: 0.815306
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7873119884981199
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.787312
# 	best_validation_score so far: 0.815306
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8080070780800708
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.808007
# 	best_validation_score so far: 0.815306
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8079379562043796
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.807938
# 	best_validation_score so far: 0.815306
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8078688343286883
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.807869
# 	best_validation_score so far: 0.815306
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8002930767529307
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.800293
# 	best_validation_score so far: 0.815306
# roc_auc_score:
#  0.9518603293597149
# Best hyperparameters: (10, 'auto', {0: 1.0, 1: 1.0})
# train_score: 0.951860
# validation_score: 0.815306
# #################
# (10, 'auto', {0: 1.0, 1: 1.0})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 1.0},
#                                           n_estimators=10),
#              model_dir='/tmp/tmpknhk05_6')
# roc_auc_score:
#  0.8085032837884548
# precision_score:
#  0.7572815533980582
# accuracy_score:
#  0.8066914498141264
# confusion_matrix:
#  [[200  75]
#  [ 29 234]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       275
#            1       0.76      0.89      0.82       263
#
#     accuracy                           0.81       538
#    macro avg       0.82      0.81      0.81       538
# weighted avg       0.82      0.81      0.81       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8223982525989825
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.822398
# 	best_validation_score so far: 0.822398
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7996709798717099
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.799671
# 	best_validation_score so far: 0.822398
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7873119884981199
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.787312
# 	best_validation_score so far: 0.822398
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8077305905773059
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.807731
# 	best_validation_score so far: 0.822398
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8134124087591241
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.813412
# 	best_validation_score so far: 0.822398
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8201587038265871
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.820159
# 	best_validation_score so far: 0.822398
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8186103738111038
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.818610
# 	best_validation_score so far: 0.822398
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8393054633930547
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.839305
# 	best_validation_score so far: 0.839305
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8301122539261225
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.830112
# 	best_validation_score so far: 0.839305
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.822536496350365
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.822536
# 	best_validation_score so far: 0.839305
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8282874364078745
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.828287
# 	best_validation_score so far: 0.839305
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.821914399469144
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.821914
# 	best_validation_score so far: 0.839305
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8264626188896261
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.826463
# 	best_validation_score so far: 0.839305
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8165090687900908
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.816509
# 	best_validation_score so far: 0.839305
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.807108493696085
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.807108
# 	best_validation_score so far: 0.839305
# roc_auc_score:
#  0.9476849576010815
# Best hyperparameters: (100, 'auto', {0: 1.0, 1: 5})
# train_score: 0.947685
# validation_score: 0.839305
# #################
# (100, 'auto', {0: 1.0, 1: 5})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 5}),
#              model_dir='/tmp/tmpk0rvi4zr')
# roc_auc_score:
#  0.8098237124092637
# precision_score:
#  0.7702702702702703
# accuracy_score:
#  0.8085501858736059
# confusion_matrix:
#  [[207  68]
#  [ 35 228]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       275
#            1       0.77      0.87      0.82       263
#
#     accuracy                           0.81       538
#    macro avg       0.81      0.81      0.81       538
# weighted avg       0.81      0.81      0.81       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7773584383985844
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.777358
# 	best_validation_score so far: 0.777358
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.805352798053528
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.805353
# 	best_validation_score so far: 0.805353
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8073158593231585
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.807316
# 	best_validation_score so far: 0.807316
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7963669542136694
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.796367
# 	best_validation_score so far: 0.807316
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7942656491926564
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.794266
# 	best_validation_score so far: 0.807316
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8017722848927229
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.801772
# 	best_validation_score so far: 0.807316
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7815610484406105
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.781561
# 	best_validation_score so far: 0.807316
# Fitting model 8/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7701282902012829
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.770128
# 	best_validation_score so far: 0.807316
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7883764653837646
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.788376
# 	best_validation_score so far: 0.807316
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8110346162353461
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.811035
# 	best_validation_score so far: 0.811035
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8018414067684141
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.801841
# 	best_validation_score so far: 0.811035
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7958139792081399
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.795814
# 	best_validation_score so far: 0.811035
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8167164344171643
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.816716
# 	best_validation_score so far: 0.816716
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7922334660473347
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.792233
# 	best_validation_score so far: 0.816716
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7980535279805354
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.798054
# 	best_validation_score so far: 0.816716
# roc_auc_score:
#  0.9447102200714368
# Best hyperparameters: (100, 'log2', {0: 1.0, 1: 5})
# train_score: 0.944710
# validation_score: 0.816716
# #################
# (100, 'log2', {0: 1.0, 1: 5})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 5},
#                                           max_features='log2'),
#              model_dir='/tmp/tmpepbps2fw')
# roc_auc_score:
#  0.7887911966379119
# precision_score:
#  0.7622377622377622
# accuracy_score:
#  0.7881040892193308
# confusion_matrix:
#  [[206  68]
#  [ 46 218]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       274
#            1       0.76      0.83      0.79       264
#
#     accuracy                           0.79       538
#    macro avg       0.79      0.79      0.79       538
# weighted avg       0.79      0.79      0.79       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.781804355340477
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.781804
# 	best_validation_score so far: 0.781804
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7853577601106119
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.785358
# 	best_validation_score so far: 0.785358
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7895748358105772
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.789575
# 	best_validation_score so far: 0.789575
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7816384376080194
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.781638
# 	best_validation_score so far: 0.789575
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7728793639820255
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.772879
# 	best_validation_score so far: 0.789575
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7873418596612513
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.787342
# 	best_validation_score so far: 0.789575
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7908123055651572
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.790812
# 	best_validation_score so far: 0.790812
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8076736951261667
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.807674
# 	best_validation_score so far: 0.807674
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8169305219495333
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.816931
# 	best_validation_score so far: 0.816931
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.805772554441756
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.805773
# 	best_validation_score so far: 0.816931
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8080055305910818
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.808006
# 	best_validation_score so far: 0.816931
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.796598686484618
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.796599
# 	best_validation_score so far: 0.816931
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8017213964742482
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.801721
# 	best_validation_score so far: 0.816931
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7997372969236087
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.799737
# 	best_validation_score so far: 0.816931
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7975872796405116
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.797587
# 	best_validation_score so far: 0.816931
# roc_auc_score:
#  0.970240875015362
# Best hyperparameters: (100, 'auto', {0: 1.0, 1: 10})
# train_score: 0.970241
# validation_score: 0.816931
# #################
# (100, 'auto', {0: 1.0, 1: 10})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 10}),
#              model_dir='/tmp/tmpczlnmtok')
# roc_auc_score:
#  0.8267391063923909
# precision_score:
#  0.775974025974026
# accuracy_score:
#  0.8252788104089219
# confusion_matrix:
#  [[205  69]
#  [ 25 239]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81       274
#            1       0.78      0.91      0.84       264
#
#     accuracy                           0.83       538
#    macro avg       0.83      0.83      0.82       538
# weighted avg       0.83      0.83      0.82       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# RDKit ERROR: [17:10:13] Explicit valence for atom # 0 P, 11, is greater than permitted
# error in smile: [P](OCC=C(C)C)(OCC=C(C)C)(=O)(OP(OCC=C(C)C)(OCC=C(C)C)=O)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)CC=C(C)C
# Featurizing datapoint 2000
# Elements with indexes:  [1218]  were removed due to the presence of NAs!
# The elements in question are:  ['[P](OCC=C(C)C)(OCC=C(C)C)(=O)(OP(OCC=C(C)C)(OCC=C(C)C)=O)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)(CC=C(C)C)CC=C(C)C']
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8151123401313516
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.815112
# 	best_validation_score so far: 0.815112
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8039543726235742
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.803954
# 	best_validation_score so far: 0.815112
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8118078119599031
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.811808
# 	best_validation_score so far: 0.815112
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7931282405807121
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.793128
# 	best_validation_score so far: 0.815112
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8313930176287591
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.831393
# 	best_validation_score so far: 0.831393
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8118078119599031
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.811808
# 	best_validation_score so far: 0.831393
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8186657449014862
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.818666
# 	best_validation_score so far: 0.831393
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8460214310404425
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.846021
# 	best_validation_score so far: 0.846021
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8279225717248531
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.827923
# 	best_validation_score so far: 0.846021
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8318078119599033
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.831808
# 	best_validation_score so far: 0.846021
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8338748703767717
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.833875
# 	best_validation_score so far: 0.846021
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8357760110611822
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.835776
# 	best_validation_score so far: 0.846021
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.8302385067404079
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.830239
# 	best_validation_score so far: 0.846021
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8229657794676807
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.822966
# 	best_validation_score so far: 0.846021
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8204839267196681
# ...
# roc_auc_score:
#  0.9587049199216499
# Best hyperparameters: (100, 'sqrt', {0: 1.0, 1: 10})
# train_score: 0.958705
# validation_score: 0.813620
# #################
# (100, 'sqrt', {0: 1.0, 1: 10})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 10},
#                                           max_features='sqrt'),
#              model_dir='/tmp/tmpeuwgb0mx')
# roc_auc_score:
#  0.8090715549657156
# precision_score:
#  0.7864768683274022
# accuracy_score:
#  0.8085501858736059
# confusion_matrix:
#  [[214  60]
#  [ 43 221]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81       274
#            1       0.79      0.84      0.81       264
#
#     accuracy                           0.81       538
#    macro avg       0.81      0.81      0.81       538
# weighted avg       0.81      0.81      0.81       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# RDKit ERROR: [17:10:46] Explicit valence for atom # 1 Cl, 9, is greater than permitted
# error in smile: O=[Cl-](=O)(=O)=O
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Elements with indexes:  [384]  were removed due to the presence of NAs!
# The elements in question are:  ['O=[Cl-](=O)(=O)=O']
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7740544127405442
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.774054
# 	best_validation_score so far: 0.774054
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7869663791196637
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.786966
# 	best_validation_score so far: 0.786966
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7737779252377792
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.773778
# 	best_validation_score so far: 0.786966
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7814228046892281
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.781423
# 	best_validation_score so far: 0.786966
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7856945366069454
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.785695
# 	best_validation_score so far: 0.786966
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7911689891616899
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.791169
# 	best_validation_score so far: 0.791169
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7893441716434416
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.789344
# 	best_validation_score so far: 0.791169
# Fitting model 8/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7826255253262553
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.782626
# 	best_validation_score so far: 0.791169
# Fitting model 9/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7791832559168326
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.779183
# 	best_validation_score so far: 0.791169
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7906851360318513
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.790685
# 	best_validation_score so far: 0.791169
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.8184030081840302
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.818403
# 	best_validation_score so far: 0.818403
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.8001548330015484
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.800155
# 	best_validation_score so far: 0.818403
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7975696748506966
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.797570
# 	best_validation_score so far: 0.818403
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7943347710683477
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.794335
# 	best_validation_score so far: 0.818403
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.784934195974342
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.784934
# 	best_validation_score so far: 0.818403
# roc_auc_score:
#  0.9629335492086705
# Best hyperparameters: (100, 'log2', {0: 1.0, 1: 1.0})
# train_score: 0.962934
# validation_score: 0.818403
# #################
# (100, 'log2', {0: 1.0, 1: 1.0})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 1.0},
#                                           max_features='log2'),
#              model_dir='/tmp/tmpsckd28fr')
# roc_auc_score:
#  0.7934531628067751
# precision_score:
#  0.7923076923076923
# accuracy_score:
#  0.7936802973977695
# confusion_matrix:
#  [[221  54]
#  [ 57 206]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       275
#            1       0.79      0.78      0.79       263
#
#     accuracy                           0.79       538
#    macro avg       0.79      0.79      0.79       538
# weighted avg       0.79      0.79      0.79       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# RDKit ERROR: [17:10:55] Explicit valence for atom # 1 Cl, 4, is greater than permitted
# error in smile: O=[Cl]=O
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Elements with indexes:  [697]  were removed due to the presence of NAs!
# The elements in question are:  ['O=[Cl]=O']
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7402399911523999
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.740240
# 	best_validation_score so far: 0.740240
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7576310550763106
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.757631
# 	best_validation_score so far: 0.757631
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7579075425790754
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.757908
# 	best_validation_score so far: 0.757908
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7483687237336872
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.748369
# 	best_validation_score so far: 0.757908
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7495714443707144
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.749571
# 	best_validation_score so far: 0.757908
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7519492368944923
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.751949
# 	best_validation_score so far: 0.757908
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7739852908648529
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.773985
# 	best_validation_score so far: 0.773985
# Fitting model 8/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7478848706038488
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.747885
# 	best_validation_score so far: 0.773985
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7680961070559611
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.768096
# 	best_validation_score so far: 0.773985
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7741235346162354
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.774124
# 	best_validation_score so far: 0.774124
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7781879009068791
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.778188
# 	best_validation_score so far: 0.778188
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7704047777040479
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.770405
# 	best_validation_score so far: 0.778188
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7641699845166998
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.764170
# 	best_validation_score so far: 0.778188
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.781699292191993
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.781699
# 	best_validation_score so far: 0.781699
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7791832559168326
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.779183
# 	best_validation_score so far: 0.781699
# roc_auc_score:
#  0.9452236813606291
# Best hyperparameters: (100, 'log2', {0: 1.0, 1: 5})
# train_score: 0.945224
# validation_score: 0.781699
# #################
# (100, 'log2', {0: 1.0, 1: 5})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 5},
#                                           max_features='log2'),
#              model_dir='/tmp/tmpnraun1yf')
# roc_auc_score:
#  0.7898237124092636
# precision_score:
#  0.742671009771987
# accuracy_score:
#  0.7881040892193308
# confusion_matrix:
#  [[196  79]
#  [ 35 228]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77       275
#            1       0.74      0.87      0.80       263
#
#     accuracy                           0.79       538
#    macro avg       0.80      0.79      0.79       538
# weighted avg       0.80      0.79      0.79       538
#
# WARNING: task averager  cannot perform reduce with flexible type
# Featurizing datapoint 0
# Featurizing datapoint 1000
# Featurizing datapoint 2000
# Fitting 15 random models from a space of 24 possible models.
# Fitting model 1/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7328024773280247
# Model 1/15, Metric roc_auc_score, Validation set 1: 0.732802
# 	best_validation_score so far: 0.732802
# Fitting model 2/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7744691439946914
# Model 2/15, Metric roc_auc_score, Validation set 2: 0.774469
# 	best_validation_score so far: 0.774469
# Fitting model 3/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7704738995797389
# Model 3/15, Metric roc_auc_score, Validation set 3: 0.770474
# 	best_validation_score so far: 0.774469
# Fitting model 4/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7708886308338863
# Model 4/15, Metric roc_auc_score, Validation set 4: 0.770889
# 	best_validation_score so far: 0.774469
# Fitting model 5/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7835932315859323
# Model 5/15, Metric roc_auc_score, Validation set 5: 0.783593
# 	best_validation_score so far: 0.783593
# Fitting model 6/15
# hyperparameters: {'n_estimators': 10, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7590411413404113
# Model 6/15, Metric roc_auc_score, Validation set 6: 0.759041
# 	best_validation_score so far: 0.783593
# Fitting model 7/15
# hyperparameters: {'n_estimators': 10, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7776349259013493
# Model 7/15, Metric roc_auc_score, Validation set 7: 0.777635
# 	best_validation_score so far: 0.783593
# Fitting model 8/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'auto', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7838697190886972
# Model 8/15, Metric roc_auc_score, Validation set 8: 0.783870
# 	best_validation_score so far: 0.783870
# Fitting model 9/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7608659588586596
# Model 9/15, Metric roc_auc_score, Validation set 9: 0.760866
# 	best_validation_score so far: 0.783870
# Fitting model 10/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7763630833886308
# Model 10/15, Metric roc_auc_score, Validation set 10: 0.776363
# 	best_validation_score so far: 0.783870
# Fitting model 11/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'sqrt', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.781975779694758
# Model 11/15, Metric roc_auc_score, Validation set 11: 0.781976
# 	best_validation_score so far: 0.783870
# Fitting model 12/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 1.0}}
# roc_auc_score:
#  0.7739161689891616
# Model 12/15, Metric roc_auc_score, Validation set 12: 0.773916
# 	best_validation_score so far: 0.783870
# Fitting model 13/15
# hyperparameters: {'n_estimators': 100, 'max_features': 'log2', 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.776432205264322
# Model 13/15, Metric roc_auc_score, Validation set 13: 0.776432
# 	best_validation_score so far: 0.783870
# Fitting model 14/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 5}}
# roc_auc_score:
#  0.7816301703163018
# Model 14/15, Metric roc_auc_score, Validation set 14: 0.781630
# 	best_validation_score so far: 0.783870
# Fitting model 15/15
# hyperparameters: {'n_estimators': 100, 'max_features': None, 'class_weight': {0: 1.0, 1: 10}}
# roc_auc_score:
#  0.7942656491926564
# Model 15/15, Metric roc_auc_score, Validation set 15: 0.794266
# 	best_validation_score so far: 0.794266
# roc_auc_score:
#  0.9586385721505455
# Best hyperparameters: (100, None, {0: 1.0, 1: 10})
# train_score: 0.958639
# validation_score: 0.794266
# #################
# (100, None, {0: 1.0, 1: 10})
# SklearnModel(model=RandomForestClassifier(class_weight={0: 1.0, 1: 10},
#                                           max_features=None),
#              model_dir='/tmp/tmp9rkzfa9c')
# roc_auc_score:
#  0.7606897886934395
# precision_score:
#  0.7418181818181818
# accuracy_score:
#  0.7602230483271375
# confusion_matrix:
#  [[205  71]
#  [ 58 204]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       276
#            1       0.74      0.78      0.76       262
#
#     accuracy                           0.76       538
#    macro avg       0.76      0.76      0.76       538
# weighted avg       0.76      0.76      0.76       538
#
# WARNING: task averager  cannot perform reduce with flexible type
